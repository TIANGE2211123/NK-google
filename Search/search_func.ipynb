# %%
import os
import pandas as pd
import ijson  # For incremental JSON parsing
from jieba import cut_for_search
from datetime import datetime,timedelta
import math
import time
import re

# %%
# 获取脚本所在的绝对路径
#parent_dir = os.path.dirname(os.path.abspath(__file__))
parent_dir = os.getcwd()

# 获取上一级目录
base_dir = os.path.dirname(parent_dir)

print("脚本所在目录:", parent_dir)
print("脚本上一级目录:", base_dir)

# 定义子目录的路径
path = os.path.join(base_dir, "index", "jsons")
rank_path = os.path.join(base_dir, "rank")
spider_path = os.path.join(base_dir, "spider")

# 检查文件夹是否存在
if not os.path.exists(path):
    raise FileNotFoundError(f"Directory not found: {path}")
if not os.path.exists(rank_path):
    raise FileNotFoundError(f"Directory not found: {rank_path}")
if not os.path.exists(spider_path):
    raise FileNotFoundError(f"Directory not found: {spider_path}")

# Incremental JSON loader
def load_json_incrementally(file_path):
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"File not found: {file_path}")
    data = {}
    with open(file_path, 'r', encoding='utf-8') as f:
        parser = ijson.items(f, "item")
        for key, value in ijson.kvitems(f, ""):
            if key not in data:
                data[key] = value
    return data


# Load JSON files with memory efficiency
invert_index = load_json_incrementally(os.path.join(path, "invert_index.json"))
invert_index_title = load_json_incrementally(os.path.join(path, "invert_index_title.json"))
tf_idf = load_json_incrementally(os.path.join(path, "tf-idf.json"))
tf_idf_title = load_json_incrementally(os.path.join(path, "tf-idf_title.json"))
word_frequency = load_json_incrementally(os.path.join(path, "allTF.json"))
word_frequency_title = load_json_incrementally(os.path.join(path, "allTF_title.json"))
tf = load_json_incrementally(os.path.join(path, "tf.json"))
tf_title = load_json_incrementally(os.path.join(path, "tf_title.json"))
idf = load_json_incrementally(os.path.join(path, "idf.json"))
idf_title = load_json_incrementally(os.path.join(path, "idf_title.json"))

# 排序词集合
word_set = sorted(set(word_frequency.keys()))
word_set_title = sorted(set(word_frequency_title.keys()))

# 读取 CSV 文件
page_rank = pd.read_csv(os.path.join(rank_path, "page_rank_allnews.csv"), encoding='utf-8-sig')
all_info = pd.read_csv(os.path.join(spider_path, "all_news.csv"), encoding='utf-8')

print("数据加载完成！")
# Out:
# 脚本所在目录: e:\fifth_semester\Information _Retrieve\2211123_张天歌_hw4\Search Engine\Search
# 脚本上一级目录: e:\fifth_semester\Information _Retrieve\2211123_张天歌_hw4\Search Engine
# 数据加载完成！

# %%
# 将 all_info 和 page_rank 转换为字典
all_info_dict = all_info.set_index('url').to_dict(orient='index')
page_rank_dict = page_rank.set_index('url')['page_rank'].to_dict()

# %%
all_info
# Out:
#                                              title  \
# 0                  健康报：创新DNA存储方案破解医疗数据存储难题-天津大学新闻网
# 1                      天津教育报：校企共探产教协同发展新路径-天津大学新闻网
# 2       中国新闻网：新质生产力与人才培养论坛召开，校企共探产教协同发展新路径-天津大学新闻网
# 3                     央广网：新质生产力与人才培养论坛在津召开-天津大学新闻网
# 4                     中国科学报：校企共商新质生产力与人才培养-天津大学新闻网
# ...                                            ...
# 102842               天津市来校督导检查秋季学期开学准备工作-南开要闻-南开大学
# 102843              南开大学一批教师和集体获得天津市荣誉表彰-南开要闻-南开大学
# 102844                           校领导出访韩国-南开要闻-南开大学
# 102845    佛系“南开人”实力开战  勇夺《一站到底》世界名校争霸赛冠军-南开要闻-南开大学
# 102846          南开大学今日推出10门叶嘉莹诗词讲座与公开课视频-南开要闻-南开大学
#
#                                                       url  \
# 0             https://news.tju.edu.cn/info/1005/73323.htm
# 1             https://news.tju.edu.cn/info/1005/73306.htm
# 2             https://news.tju.edu.cn/info/1005/73309.htm
# 3             https://news.tju.edu.cn/info/1005/73308.htm
# 4             https://news.tju.edu.cn/info/1005/73307.htm
# ...                                                   ...
# 102842  http://news.nankai.edu.cn/ywsd/system/2018/09/...
# 102843  http://news.nankai.edu.cn/ywsd/system/2018/09/...
# 102844  http://news.nankai.edu.cn/ywsd/system/2018/09/...
# 102845  http://news.nankai.edu.cn/ywsd/system/2018/09/...
# 102846  http://news.nankai.edu.cn/ywsd/system/2024/11/...
#
#                                                   content          date  \
# 0       健康报讯（特约记者 李哲 通讯员 赵晖）天津大学合成生物学研究团队与天津市环湖医院携手，提出...  1.730477e+09
# 1       天津教育报讯（记者 刘东岳 通讯员 潘静洲）11月20日，“新质生产力与人才培养论坛”在天开...  1.730477e+09
# 2       中新网天津新闻11月21日电 11月20日，“新质生产力与人才培养论坛”在天开高教科创园召开...  1.730477e+09
# 3       央广网讯（记者 张强）11月20日，“新质生产力与人才培养论坛”在天开高教科创园召开。本次论...  1.730477e+09
# 4       中国科学报讯（记者 潘静洲 陈彬）11月20日，“新质生产力与人才培养论坛”在天津市天开高教...  1.730477e+09
# ...                                                   ...           ...
# 102842  通讯员 王芃 摄影 聂际慈)9月4日，天津市教委、市政府教育督导室督导检查组来我校督导检查秋...  1.536077e+09
# 102843  (记者 马超)在第34个教师节到来之际，南开大学教师获奖消息不断、捷报频传。继化学学院教授周...  1.536077e+09
# 102844  (通讯员 张萌)8月30日至9月3日，副校长朱光磊率团出访韩国仁川市、首尔市及釜山市高校，并...  1.536163e+09
# 102845  (记者 郝静秋)9月3日晚，在江苏卫视《一站到底》世界名校争霸赛第五季总决赛中，南开大学商学...  1.536077e+09
# 102846  （记者 王涵）11月24日，“诗词的女儿”、南开大学中华诗教与古典文化研究所所长叶嘉莹先生与...  1.730477e+09
#
#               editor                                        description  \
# 0       （编辑 刘延俊 贺泳迪）                    健康报：创新DNA存储方案破解医疗数据存储难题-天津大学新闻网
# 1       （编辑 焦德芳 郭新婷）                        天津教育报：校企共探产教协同发展新路径-天津大学新闻网
# 2       （编辑 刘延俊 贺泳迪）         中国新闻网：新质生产力与人才培养论坛召开，校企共探产教协同发展新路径-天津大学新闻网
# 3       （编辑 焦德芳 郭新婷）                       央广网：新质生产力与人才培养论坛在津召开-天津大学新闻网
# 4       （编辑 焦德芳 郭新婷）                       中国科学报：校企共商新质生产力与人才培养-天津大学新闻网
# ...              ...                                                ...
# 102842            蓝芳  南开新闻网讯(通讯员 王芃 摄影 聂际慈)9月4日，天津市教委、市政府教育督导室督导检查组来...
# 102843            蓝芳  南开新闻网讯(记者 马超)在第34个教师节到来之际，南开大学教师获奖消息不断、捷报频传。继化...
# 102844            蓝芳  南开新闻网讯(通讯员 张萌)8月30日至9月3日，副校长朱光磊率团出访韩国仁川市、首尔市及釜...
# 102845            蓝芳  南开新闻网讯(记者 郝静秋)9月3日晚，在江苏卫视《一站到底》世界名校争霸赛第五季总决赛中，...
# 102846           高雨桐  南开新闻网讯（记者王涵）11月24日，诗词的女儿、南开大学中华诗教与古典文化研究所所长叶嘉莹...
#
#        doc_link
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 102842      NaN
# 102843      NaN
# 102844      NaN
# 102845      NaN
# 102846      NaN
#
# [102847 rows x 7 columns]

# %%
# 这个函数主要用于计算输入字符串和历史记录的TF值，文档库的TF值和IDF值我们已经通过前期数据处理得到
def getTF(words, input):
    # 初始化一个词频字典，key为传入的所有的词，value为0
    tf = dict.fromkeys(words, 0)
    for word in input:
        if word in words:
            tf[word] += 1
    for word, count in tf.items():
        tf[word] = math.log10(count + 1)
    return tf

def getTF_IDF(tf, idf):
    tfidf = {}
    for word, count in tf.items():
        tfidf[word] = float(count) * float(idf[word])
    return tfidf

def getVecLength(key:list)->float:
    """
    :param key: 关键词列表
    :return: 向量长度
    """
    length = 0
    for i in range(len(key)):
        length = length + key[i][1]**2
    return round(math.sqrt(length),2)

# %%
def simple_search(input: str, history: list, onlyTitle: bool = False, num: int = 100):
    """
    :param input: 用户输入的查询字符串
    :param history: 检索历史列表
    :param onlyTitle: 是否启动仅在标题中检索
    :param num：返回结果的数量，默认为100条最相似的
    :return: 一个列表，元素为URL和相似度组成的元组
    """
    
    # 对输入中的通配符替换为正则表达式
    wildcard_to_regex = lambda s: re.sub(r"(\*)", ".*", re.sub(r"(\?)", ".", re.escape(s)))
    regex_query = wildcard_to_regex(input)
    
    # Debug: 输出正则表达式
    print(f"Converted wildcard input to regex: {regex_query}")
    
    regex = r'[\.\^\$\*\+\?\{\}\[\]\|\(\)]'
    isRe = re.search(regex, input)
    if isRe is not None:
        input = re.sub(regex, '', input)
    
    spilt_input = sorted(list(cut_for_search(input)))
    spilt_input = [term for term in spilt_input if term not in ["", " "]]
    spilt_history = []
    for i in range(len(history)):
        ls = list(cut_for_search(history[i]))
        ls = [term for term in ls if term not in ["", " "]]
        spilt_history.extend(ls)
    
    # 输出分词结果
    print(f"Spilt input: {spilt_input}")
    print(f"Spilt history: {spilt_history}")
    
    # 判断用户需要的搜索模式
    if onlyTitle:
        tf_dict = tf_title  # 读取的json数据
        idf_dict = idf_title
        words = word_set_title
    else:
        tf_dict = tf
        idf_dict = idf
        words = word_set
    
    tfidf_dict = {}
    for key, value in tf_dict.items():
        tfidf_dict[key] = getTF_IDF(value, idf_dict)
    
    # 存储关键词的tfidf值，找到num个最大的
    key_tfidf_dict = {}
    for key, value in tfidf_dict.items():
        key_tfidf_dict[key] = sorted(tfidf_dict[key].items(), key=lambda item: item[1], reverse=True)[0:num]
    
    # 保存关键词字典的key与value
    key_tfidf_dict_keys = list(key_tfidf_dict.keys())  # 即url组成的列表
    key_tfidf_dict_values = list(key_tfidf_dict.values())
    
    # 用户输入查询的TFIDF
    tf_input = getTF(words, spilt_input)
    tfidf_input = getTF_IDF(tf_input, idf_dict)
    key_input = sorted(tfidf_input.items(), key=lambda item: item[1], reverse=True)[0:num]
    len_key_input = getVecLength(key_input)
    
    # Validate input vector length
    if len_key_input == 0:
        raise ValueError("Input query resulted in an empty vector. Please refine your search query.")
    
    # 历史记录的TFIDF
    tf_history = getTF(words, spilt_history)
    tfidf_history = getTF_IDF(tf_history, idf_dict)
    key_history = sorted(tfidf_history.items(), key=lambda item: item[1], reverse=True)[0:num]
    len_key_history = getVecLength(key_history)
    
    # 如果词库里没有搜索项，那么返回错误
    if len_key_input == 0:
        print("调试信息：key_input为空，用户输入的关键词未在词库中找到。")
        raise KeyError("用户输入的关键词未找到，请检查索引或输入的正确性。")
    
    # 向量空间模型，计算余弦相似度
    key_results = []  # 用于存储余弦相似度
    key_results_index = []  # 记录文档索引
    for i in range(len(key_tfidf_dict_keys)):
        length = 0
        temp_list = key_tfidf_dict_values[i]
        # 遍历每个输入关键词
        for key in key_input:
            if key[1] != 0:  # tf-idf值不为0才存在相似度
                # 遍历文档内的每个关键词
                for value in temp_list:
                    if key[0] == value[0]:
                        length = length + key[1] * value[1]
        res = getVecLength(temp_list)
        if res == 0.0:
            continue
        # 余弦相似度
        sim = round(length / (len_key_input * res), 4)
        
        key_results.append((key_tfidf_dict_keys[i], sim))
        if sim > 0:
            key_results_index.append(i)
    
    if len(history) > 0:
        history_results_dict = {}
        for item in key_results_index:
            length = 0
            temp_list = key_tfidf_dict_values[item]
            for _key_history in key_history:
                if _key_history[1] != 0:
                    for value in temp_list:
                        if _key_history[0] == value[0]:
                            length = length + _key_history[1] * value[1]
            sim = round(length / (len_key_history * getVecLength(temp_list)), 4)
            history_results_dict[item] = (key_tfidf_dict_keys[item], sim)
        
        results = []
        for i in range(len(key_tfidf_dict_keys)):
            if i >= len(key_results):
                break
            #print(f"Key results输出结果调试: {key_results[i][1]}")
            if key_results[i][1] == 0:
                pass
            elif j := history_results_dict.get(i):
                # 设置历史记录的权重为0.1
                results.append((key_results[i][0], key_results[i][1] + j[1] / 10))
            else:
                results.append((key_results[i][0], key_results[i][1]))
        results = sorted(results, key=lambda item: item[1], reverse=True)
    # 没有历史记录时，直接利用字典计算余弦相似度即可
    else:
        results = []
        for i in range(len(key_tfidf_dict_keys)):
            if i >= len(key_results):
                break
            results.append((key_results[i][0], key_results[i][1]))
        results = sorted(results, key=lambda item: item[1], reverse=True)
    
    ls, ans = [], []
    for res in results:
        if res[1] > 0:
            ls.append((res[0], res[1]))
    if isRe is not None:
        for item in ls:
            row = all_info_dict.get(item[0])
            # if re.search(escaped_input, str(row['title'])) is not None or re.search(escaped_input, str(row['description'])) is not None or re.search(escaped_input, str(row['description'])) is not None:
            #     ans.append(item)
            if re.search(regex_query, row['title']) or re.search(regex_query, row['description']):
                ans.append(item)
    if isRe is None:
        return ls
    return ans

# %%
def simple_search_test(input:str,history:list):
    time1 = time.time()
    ret = simple_search(input,history)
    print("在全文中出现的结果：")
    time2 = time.time()
    for item in ret:
        print(item)
    print("在"+str(time2-time1)+"秒时间内响应，返回"+str(len(ret))+"项结果")

    time1 = time.time()
    ret = simple_search(input,history,True)
    time2 = time.time()
    print("仅在标题中出现的结果：")
    for item in ret:
        print(item)
    print("在" + str(time2 - time1) + "秒时间内响应，返回" + str(len(ret)) + "项结果")

# %%
def expand_results(results: list):
    expanded = []
    for res in results:
        url = res[0]
        
        # 从字典中查找 all_info
        row = all_info_dict.get(url)
        if row is None:
            print(f"URL {url} 不存在于 all_info 中，跳过该项。")
            continue
        
        title = str(row['title']).replace("_", "/")
        dsp = str(row['description'])
        
        # 从字典中查找 page_rank 值，默认为 0
        page_rank_value = page_rank_dict.get(url, 0)
        if page_rank_value == 0:
            print(f"URL {url} 不存在于 page_rank 中，使用默认值 0 计算综合得分。")
        
        # 计算综合得分
        score = res[1] * 0.7 + 0.3 * page_rank_value
        expanded.append((title, url, dsp, score))
    
    # 按综合得分排序
    return sorted(expanded, key=lambda item: item[-1], reverse=True)


# 测试函数：接收输入和历史记录，并打印结果
def expand_results_test(input: str, history: list):
    results = simple_search(input, history, True)  # 假设 simple_search 返回一个结果列表
    expanded = expand_results(results)
    for entry in expanded:
        print(entry)

# %%
# 带有发布时间限制的搜索函数
def check_time(result,limit):
    """
    :param result: simple_search返回结果拓展后的结果的一行
    :param limit：时间限制字符串
    :return: 是否满足要求
    """
    row = all_info_dict.get(result[1])
    if str(row['date']) != "nan":
        # 将时间戳转换为datetime
        articleTime = datetime.fromtimestamp(int(row['date']))
        res = datetime.now() - articleTime
        if limit == "一周内":
            if res > timedelta(days=7):
                return False
        elif limit == "一个月内":
            if res > timedelta(days=30):
                return False
        elif limit == "一年内":
            if res > timedelta(days=365):
                return False
    if str(row['date']) == "nan":
        return False
    return True

def check_time_test(input,limit):
    ret = simple_search(input,[])
    expanded = expand_results(ret)
    print("时间限制添加前的结果，共有"+str(len(expanded))+"条：")
    for item in expanded:
        print(item)
    expanded = [item for item in expanded if check_time(item,limit)==True]
    print("时间限制添加后的结果，共有"+str(len(expanded))+"条：")
    for item in expanded:
        print(item)

# %%
# 检查是不是指定的域名或者网站
def check_website(result,name):
    if name not in result[1]:
        return False
    return True

def check_website_test(input,name):
    ret = simple_search(input,[])
    expanded = expand_results(ret)
    print(f"网站或域名限制前的结果，共有{len(expanded)}条：")
    for item in expanded:
        print(item)
    expanded = [item for item in expanded if check_website(item,name)==True]
    print(f"网站或域名限制后的结果，共有{len(expanded)}条：")
    for item in expanded:
        print(item)

# %%
# 检查是否和规定的词匹配，传入一个标志位代表是否进行完全匹配
# 如果不进行完全匹配，那么只要出现一个词就可以判定为True
def check_match_words(result,input,complete=True):
    row = all_info_dict.get(result[1])  
    text = f"{row['title']}#{row['description']}#{row['content']}#{row['editor']}"
    ls = str(input).split(" ")
    for word in ls:
        if word == '#':
            pass
        if word not in text:
            if complete == True:
                return False
        if word in text:
            if complete == False:
                return True
    if complete == True:
        return True
    return False

def check_complete_match_test(input,limit):
    ret = simple_search(input,[])
    expanded = expand_results(ret)
    print(f"限制前的结果，共有{len(expanded)}条：")
    expanded = [item for item in expanded if check_match_words(item,limit,True) == True]
    print(f"包含以下所有词限制后的结果，共有{len(expanded)}条：")
    for item in expanded:
        print(item)

# %%
# 检查是否不含一些词
def check_not_include(result,input):
    row = all_info_dict.get(result[1])
    text = f"{row['title']}#{row['description']}#{row['content']}#{row['editor']}"
    ls = str(input).split(" ")
    ls = [word for word in ls if word != '']
    for word in ls:
        if word == '#':
            pass
        if word in text:
            return False
    return True

# %%
ret = simple_search("运动",['陈雨露'])
# ret = expand_results(ret)
# ret = [item for item in ret if check_time(item,"一年内")]
# print(f"过滤时间后，剩余{len(ret)}条")
# ret = [item for item in ret if check_website(item,"nankai")]
# print(f"过滤来源后，剩余{len(ret)}条")
# ret = [item for item in ret if check_match_words(item,"校长 大学",True)]
# for item in ret:
#     print(item)
# print(f"过滤必须词后，剩余{len(ret)}条")
# check_complete_match_test("运动会","\"校长\"")
# Out:
# Converted wildcard input to regex: 运动
# Spilt input: ['运动']
# Spilt history: ['陈', '雨露']

# %%
ret
# Out:
# [('https://news.tju.edu.cn/info/1003/22222.htm', 0.3453),
#  ('https://news.tju.edu.cn/info/1003/23312.htm', 0.3453),
#  ('https://news.tju.edu.cn/info/1017/53602.htm', 0.3388),
#  ('https://news.tju.edu.cn/info/1005/19543.htm', 0.3123),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/11/01/000150335.shtml', 0.3085),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/09/27/000142434.shtml', 0.304),
#  ('https://news.tju.edu.cn/info/1016/35976.htm', 0.301),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/04/19/000038444.shtml', 0.2994),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/09/27/000142435.shtml', 0.2915),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/04/29/030033149.shtml', 0.2901),
#  ('https://news.tju.edu.cn/info/1017/53788.htm', 0.2871),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/10/22/000147795.shtml', 0.2849),
#  ('https://news.tju.edu.cn/info/1017/53794.htm', 0.2792),
#  ('https://news.tju.edu.cn/info/1017/35273.htm', 0.278),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/12/10/000259997.shtml', 0.2776),
#  ('http://news.nankai.edu.cn/ztbd/system/2012/10/20/000094357.shtml', 0.2745),
#  ('https://news.tju.edu.cn/info/1003/53715.htm', 0.2711),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/12/10/000158977.shtml', 0.2709),
#  ('https://news.tju.edu.cn/info/1017/37342.htm', 0.2707),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/04/18/000038399.shtml', 0.2706),
#  ('http://news.nankai.edu.cn/zhxw/system/2009/10/23/000026399.shtml', 0.2687),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/12/26/000051334.shtml', 0.2664),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/12/10/000259999.shtml', 0.2601),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/09/28/000142694.shtml', 0.2569),
#  ('https://news.tju.edu.cn/info/1005/21704.htm', 0.2559),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/09/27/000142475.shtml', 0.2532),
#  ('http://news.nankai.edu.cn/dcxy/system/2012/10/22/000094894.shtml', 0.2512),
#  ('https://news.tju.edu.cn/info/1003/22244.htm', 0.2461),
#  ('http://news.nankai.edu.cn/ywsd/system/2014/09/28/000202897.shtml', 0.2457),
#  ('https://news.tju.edu.cn/info/1012/38003.htm', 0.2455),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/09/27/000142478.shtml', 0.2441),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/09/28/000142575.shtml', 0.2437),
#  ('https://news.tju.edu.cn/info/1017/38669.htm', 0.2422),
#  ('https://news.tju.edu.cn/info/1017/53732.htm', 0.2398),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/09/28/000142574.shtml', 0.2372),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/12/29/000036581.shtml', 0.2372),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/05/25/000235559.shtml', 0.2349),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/09/27/000142255.shtml', 0.2311),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/06/04/030033808.shtml', 0.2285),
#  ('https://news.tju.edu.cn/info/1003/23884.htm', 0.2282),
#  ('http://news.nankai.edu.cn/dcxy/system/2012/10/22/000094874.shtml', 0.2252),
#  ('https://news.tju.edu.cn/info/1003/22246.htm', 0.2161),
#  ('https://news.tju.edu.cn/info/1018/44947.htm', 0.2083),
#  ('http://news.nankai.edu.cn/ywsd/system/2012/10/06/000091134.shtml', 0.2046),
#  ('http://news.nankai.edu.cn/mtnk/system/2010/11/04/000034901.shtml', 0.2044),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/04/16/000118381.shtml', 0.1999),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/05/09/030033351.shtml', 0.1993),
#  ('https://news.tju.edu.cn/info/1017/39194.htm', 0.1971),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/04/18/000118618.shtml', 0.1931),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/05/09/030033350.shtml', 0.1912),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/03/13/000371575.shtml', 0.189),
#  ('http://news.nankai.edu.cn/mtnk/system/2023/09/19/030057945.shtml', 0.1838),
#  ('http://news.nankai.edu.cn/mtnk/system/2023/09/26/030058061.shtml', 0.1832),
#  ('https://news.tju.edu.cn/info/1003/23319.htm', 0.1814),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/03/09/000037379.shtml', 0.1802),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/05/07/000380577.shtml', 0.1786),
#  ('http://news.nankai.edu.cn/zhxw/system/2016/12/12/000310458.shtml', 0.1754),
#  ('http://news.nankai.edu.cn/ywsd/system/2015/09/26/000249835.shtml', 0.1737),
#  ('http://news.nankai.edu.cn/ztbd/system/2013/10/11/000144675.shtml', 0.1729),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/09/27/000142297.shtml', 0.1728),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/05/12/000180879.shtml', 0.1706),
#  ('http://news.nankai.edu.cn/mtnk/system/2010/10/31/000034693.shtml', 0.1682),
#  ('http://news.nankai.edu.cn/ztbd/system/2013/09/26/000142175.shtml', 0.1669),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/12/10/000260083.shtml', 0.1667),
#  ('https://news.tju.edu.cn/info/1003/23318.htm', 0.1656),
#  ('http://news.nankai.edu.cn/mtnk/system/2012/04/16/000063237.shtml', 0.1605),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/04/24/030032117.shtml', 0.1604),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/12/09/000259900.shtml', 0.1592),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/09/29/000202962.shtml', 0.1587),
#  ('http://news.nankai.edu.cn/ywsd/system/2016/09/16/000296254.shtml', 0.1582),
#  ('http://news.nankai.edu.cn/ywsd/system/2016/10/15/000299356.shtml', 0.1579),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/10/11/000144515.shtml', 0.1572),
#  ('http://news.nankai.edu.cn/mtnk/system/2010/12/10/000036192.shtml', 0.1561),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/05/15/030033485.shtml', 0.156),
#  ('http://news.nankai.edu.cn/mtnk/system/2024/09/30/030063738.shtml', 0.1549),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/11/17/000209173.shtml', 0.1538),
#  ('http://news.nankai.edu.cn/ywsd/system/2013/10/14/000145361.shtml', 0.1538),
#  ('https://news.tju.edu.cn/info/1003/22227.htm', 0.1536),
#  ('http://news.nankai.edu.cn/mtnk/system/2023/09/19/030057944.shtml', 0.1527),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/04/13/000228477.shtml', 0.1523),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/06/04/000128717.shtml', 0.152),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/05/05/030033209.shtml', 0.1514),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/04/10/000117375.shtml', 0.1512),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/12/13/000159418.shtml', 0.1509),
#  ('http://news.nankai.edu.cn/ztbd/system/2017/09/23/000346956.shtml', 0.1505),
#  ('http://news.nankai.edu.cn/ztbd/system/2017/09/24/000347134.shtml', 0.1503),
#  ('http://news.nankai.edu.cn/ywsd/system/2016/04/01/000276375.shtml', 0.1477),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/04/13/000228539.shtml', 0.1475),
#  ('http://news.nankai.edu.cn/mtnk/system/2014/04/12/000175480.shtml', 0.1469),
#  ('http://news.nankai.edu.cn/ztbd/system/2017/09/23/000346958.shtml', 0.1467),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/11/07/000207881.shtml', 0.1464),
#  ('http://news.nankai.edu.cn/mtnk/system/2017/04/01/000325774.shtml', 0.1462),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/03/09/000371043.shtml', 0.1456),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/03/24/000226396.shtml', 0.1428),
#  ('http://news.nankai.edu.cn/ywsd/system/2012/09/29/000090074.shtml', 0.1411),
#  ('http://news.nankai.edu.cn/ztbd/system/2013/10/06/000143974.shtml', 0.1409),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/12/10/000260087.shtml', 0.1402),
#  ('https://news.tju.edu.cn/info/1005/66007.htm', 0.1394),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/12/12/000423274.shtml', 0.1391),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/04/20/000064147.shtml', 0.139),
#  ('http://news.nankai.edu.cn/mtnk/system/2016/04/03/000276494.shtml', 0.1383),
#  ('http://news.nankai.edu.cn/mtnk/system/2017/05/31/000333294.shtml', 0.137),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/08/06/000017733.shtml', 0.1361),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/10/23/030035985.shtml', 0.1361),
#  ('http://news.nankai.edu.cn/mtnk/system/2012/04/15/000063198.shtml', 0.1359),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/04/30/000030226.shtml', 0.1356),
#  ('http://news.nankai.edu.cn/mtnk/system/2016/04/14/000277595.shtml', 0.1356),
#  ('http://news.nankai.edu.cn/mtnk/system/2017/04/01/000325914.shtml', 0.1356),
#  ('http://news.nankai.edu.cn/dcxy/system/2009/11/30/000027261.shtml', 0.135),
#  ('http://news.nankai.edu.cn/ywsd/system/2015/04/24/000229795.shtml', 0.1347),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/04/13/000228502.shtml', 0.1346),
#  ('http://news.nankai.edu.cn/dcxy/system/2012/10/20/000094454.shtml', 0.1343),
#  ('http://news.nankai.edu.cn/mtnk/system/2016/11/20/000306695.shtml', 0.1343),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/05/06/030033296.shtml', 0.1343),
#  ('http://news.nankai.edu.cn/ywsd/system/2018/10/13/000413116.shtml', 0.1339),
#  ('https://news.tju.edu.cn/info/1005/66091.htm', 0.1332),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/09/28/000202898.shtml', 0.1327),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/10/30/030036151.shtml', 0.1327),
#  ('http://news.nankai.edu.cn/nkdxb/system/2013/10/25/000148432.shtml', 0.1326),
#  ('http://news.nankai.edu.cn/mtnk/system/2017/10/31/000353200.shtml', 0.1322),
#  ('http://news.nankai.edu.cn/ywsd/system/2019/08/06/030034748.shtml', 0.1322),
#  ('http://news.nankai.edu.cn/ywsd/system/2024/09/23/030063609.shtml', 0.132),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/03/07/000370714.shtml', 0.1318),
#  ('http://news.nankai.edu.cn/ywsd/system/2013/10/13/000145215.shtml', 0.1317),
#  ('https://news.tju.edu.cn/info/1005/57595.htm', 0.1315),
#  ('http://news.nankai.edu.cn/mtnk/system/2017/06/09/000334238.shtml', 0.1305),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/10/29/030036121.shtml', 0.1303),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/04/13/000117834.shtml', 0.13),
#  ('http://news.nankai.edu.cn/ywsd/system/2015/04/24/000229794.shtml', 0.1294),
#  ('http://news.nankai.edu.cn/mtnk/system/2016/06/12/000284574.shtml', 0.1293),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/04/24/000229715.shtml', 0.1288),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/10/11/030035681.shtml', 0.1287),
#  ('http://news.nankai.edu.cn/ywsd/system/2019/05/05/030033266.shtml', 0.1284),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/10/28/000206716.shtml', 0.1278),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/11/18/000256278.shtml', 0.1277),
#  ('http://news.nankai.edu.cn/zhxw/system/2007/12/09/000012791.shtml', 0.1277),
#  ('https://news.tju.edu.cn/info/1005/53535.htm', 0.1276),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/05/17/030033515.shtml', 0.1276),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/07/16/030034496.shtml', 0.127),
#  ('http://news.nankai.edu.cn/dcxy/system/2012/10/20/000094448.shtml', 0.1268),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/10/01/000143554.shtml', 0.1267),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/07/29/000402335.shtml', 0.1264),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/12/23/000160854.shtml', 0.1261),
#  ('http://news.nankai.edu.cn/zhxw/system/2009/04/04/000022716.shtml', 0.1259),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/09/28/000142675.shtml', 0.1258),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/11/06/000254455.shtml', 0.1258),
#  ('http://news.nankai.edu.cn/ywsd/system/2015/12/30/000263156.shtml', 0.1258),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/12/09/000259901.shtml', 0.1256),
#  ('http://news.nankai.edu.cn/ywsd/system/2014/02/27/000167555.shtml', 0.1253),
#  ('https://news.tju.edu.cn/info/1017/37283.htm', 0.125),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/09/29/000202976.shtml', 0.1249),
#  ('http://news.nankai.edu.cn/ywsd/system/2014/09/28/000202899.shtml', 0.1244),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/10/10/000204174.shtml', 0.1241),
#  ('http://news.nankai.edu.cn/zhxw/system/2009/04/28/000023307.shtml', 0.124),
#  ('http://news.nankai.edu.cn/ywsd/system/2019/04/18/000445794.shtml', 0.124),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/09/30/000143475.shtml', 0.1236),
#  ('http://news.nankai.edu.cn/mtnk/system/2016/03/25/000275156.shtml', 0.1236),
#  ('http://news.nankai.edu.cn/mtnk/system/2023/03/24/030055043.shtml', 0.1235),
#  ('http://news.nankai.edu.cn/ywsd/system/2015/06/23/000239075.shtml', 0.12309),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/12/19/000311677.shtml', 0.1229),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/06/04/030033822.shtml', 0.1229),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/05/25/000385176.shtml', 0.1227),
#  ('http://news.nankai.edu.cn/mtnk/system/2023/08/28/030057582.shtml', 0.1225),
#  ('http://news.nankai.edu.cn/mtnk/system/2014/09/14/000200979.shtml', 0.1225),
#  ('http://news.nankai.edu.cn/dcxy/system/2012/10/21/000094634.shtml', 0.1222),
#  ('http://news.nankai.edu.cn/dcxy/system/2021/06/29/030047089.shtml', 0.1218),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/10/12/000041830.shtml', 0.1216),
#  ('http://news.nankai.edu.cn/mtnk/system/2017/08/27/000342594.shtml', 0.1216),
#  ('http://news.nankai.edu.cn/mtnk/system/2023/03/07/030054706.shtml', 0.1215),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/04/08/000173974.shtml', 0.121),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/05/10/000280475.shtml', 0.1207),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/03/13/000371580.shtml', 0.1207),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/03/23/000226236.shtml', 0.1204),
#  ('http://news.nankai.edu.cn/mtnk/system/2017/04/19/000328716.shtml', 0.1204),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/11/05/000254134.shtml', 0.1203),
#  ('http://news.nankai.edu.cn/ywsd/system/2017/09/03/000343414.shtml', 0.1198),
#  ('http://news.nankai.edu.cn/ywsd/system/2020/06/26/030039837.shtml', 0.1196),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/04/10/000117195.shtml', 0.1192),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/03/12/000169154.shtml', 0.1192),
#  ('http://news.nankai.edu.cn/mtnk/system/2017/07/30/000340381.shtml', 0.1192),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/05/25/000235598.shtml', 0.1191),
#  ('http://news.nankai.edu.cn/mtnk/system/2017/04/01/000325935.shtml', 0.1189),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/05/13/030033395.shtml', 0.1186),
#  ('http://news.nankai.edu.cn/nkzs/system/2015/04/15/000228758.shtml', 0.118),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/04/23/000229640.shtml', 0.1177),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/09/27/000142298.shtml', 0.1177),
#  ('http://news.nankai.edu.cn/mtnk/system/2016/07/03/000287154.shtml', 0.1177),
#  ('https://news.tju.edu.cn/info/1003/44764.htm', 0.1175),
#  ('http://news.nankai.edu.cn/zhxw/system/2019/06/03/030033720.shtml', 0.1174),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/10/10/000034001.shtml', 0.1173),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/04/13/000228479.shtml', 0.1173),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/10/29/000253274.shtml', 0.1167),
#  ('http://news.nankai.edu.cn/mtnk/system/2014/06/27/000190574.shtml', 0.1161),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/11/10/000043918.shtml', 0.116),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/04/30/000230355.shtml', 0.116),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/09/02/000246594.shtml', 0.116),
#  ('http://news.nankai.edu.cn/dcxy/system/2011/10/18/000041950.shtml', 0.1158),
#  ('http://news.nankai.edu.cn/ywsd/system/2013/09/27/000142275.shtml', 0.1158),
#  ('https://news.tju.edu.cn/info/1005/71125.htm', 0.1155),
#  ('https://news.tju.edu.cn/info/1003/22900.htm', 0.1148),
#  ('http://news.nankai.edu.cn/nkdxb/system/2012/04/27/000065115.shtml', 0.1148),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/07/06/000032411.shtml', 0.1148),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/10/23/030035983.shtml', 0.1148),
#  ('https://news.tju.edu.cn/info/1005/71091.htm', 0.1146),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/09/27/000142317.shtml', 0.1144),
#  ('http://news.nankai.edu.cn/mtnk/system/2023/09/18/030057928.shtml',
#   0.11424999999999999),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/04/16/000063275.shtml', 0.1141),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/01/03/000028030.shtml', 0.1138),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/04/15/000277779.shtml', 0.1135),
#  ('http://news.nankai.edu.cn/mtnk/system/2024/02/06/030060023.shtml', 0.1135),
#  ('http://news.nankai.edu.cn/mtnk/system/2017/08/27/000342577.shtml', 0.1135),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/06/11/000039664.shtml', 0.1132),
#  ('http://news.nankai.edu.cn/mtnk/system/2012/09/12/000086314.shtml', 0.1131),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/09/27/000142278.shtml', 0.113),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/05/07/000123016.shtml', 0.1129),
#  ('http://news.nankai.edu.cn/mtnk/system/2016/04/12/000277406.shtml', 0.1129),
#  ('http://news.nankai.edu.cn/nkdxb/system/2013/06/08/000129297.shtml', 0.1128),
#  ('http://news.nankai.edu.cn/zhxw/system/2009/01/04/000021158.shtml', 0.1128),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/10/11/030035680.shtml', 0.1126),
#  ('http://news.nankai.edu.cn/nkdxb/system/2012/10/17/000093617.shtml', 0.1124),
#  ('http://news.nankai.edu.cn/mtnk/system/2009/06/04/000024104.shtml', 0.1123),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/10/17/000205055.shtml', 0.1118),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/07/27/000017580.shtml', 0.1115),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/05/18/000281803.shtml', 0.1114),
#  ('http://news.nankai.edu.cn/mtnk/system/2010/07/18/000032596.shtml', 0.111),
#  ('http://news.nankai.edu.cn/dcxy/system/2018/06/14/000390677.shtml', 0.1109),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/10/29/000301900.shtml', 0.1108),
#  ('http://news.nankai.edu.cn/nkdxb/system/2012/06/07/000072204.shtml', 0.1108),
#  ('http://news.nankai.edu.cn/mtnk/system/2017/12/06/000359857.shtml', 0.1108),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/05/15/000030645.shtml', 0.1106),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/03/27/000324738.shtml', 0.1105),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/10/17/000019300.shtml', 0.1105),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/12/19/000214455.shtml', 0.1102),
#  ('http://news.nankai.edu.cn/nkdxb/system/2012/04/13/000062976.shtml', 0.1102),
#  ('http://news.nankai.edu.cn/mtnk/system/2022/09/04/030052679.shtml', 0.1102),
#  ('https://news.tju.edu.cn/info/1005/19665.htm', 0.1101),
#  ('http://news.nankai.edu.cn/ywsd/system/2019/09/13/030035221.shtml', 0.1101),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/10/23/030035984.shtml', 0.11),
#  ('http://news.nankai.edu.cn/zhxw/system/2009/10/29/000026517.shtml', 0.1096),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/06/07/000072135.shtml', 0.1096),
#  ('http://news.nankai.edu.cn/ztbd/system/2012/10/22/000094794.shtml', 0.1096),
#  ('http://news.nankai.edu.cn/zhxw/system/2009/06/29/000024518.shtml', 0.1095),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/11/12/000304875.shtml', 0.1093),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/10/31/000353098.shtml', 0.109),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/04/28/000030139.shtml', 0.109),
#  ('http://news.nankai.edu.cn/zhxw/system/2017/05/23/000332597.shtml', 0.1089),
#  ('http://news.nankai.edu.cn/zhxw/system/2014/08/14/000197054.shtml', 0.1088),
#  ('http://news.nankai.edu.cn/zhxw/system/2024/05/27/030061885.shtml', 0.1088),
#  ('http://news.nankai.edu.cn/ywsd/system/2016/07/16/000289214.shtml', 0.1088),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/04/24/000329780.shtml', 0.1087),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/05/28/000039407.shtml', 0.1087),
#  ('https://news.tju.edu.cn/info/1005/59213.htm', 0.1086),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/05/05/000330755.shtml', 0.1086),
#  ('http://news.nankai.edu.cn/zhxw/system/2009/03/27/000022439.shtml', 0.1083),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/12/05/000158136.shtml', 0.1083),
#  ('http://news.nankai.edu.cn/ywsd/system/2017/03/31/000325635.shtml', 0.1083),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/09/26/000297378.shtml', 0.1082),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/05/10/000038972.shtml', 0.1082),
#  ('http://news.nankai.edu.cn/mtnk/system/2024/10/22/030064037.shtml', 0.1082),
#  ('http://news.nankai.edu.cn/dcxy/system/2012/11/07/000098917.shtml', 0.108),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/03/30/000037950.shtml', 0.1077),
#  ('https://news.tju.edu.cn/info/1005/44773.htm', 0.1075),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/09/23/000296963.shtml', 0.1075),
#  ('http://news.nankai.edu.cn/ywsd/system/2016/05/05/000279921.shtml', 0.1074),
#  ('http://news.nankai.edu.cn/mtnk/system/2012/05/07/000067178.shtml', 0.1072),
#  ('https://news.tju.edu.cn/info/1005/69011.htm', 0.10718),
#  ('https://news.tju.edu.cn/info/1005/63291.htm', 0.10718),
#  ('https://news.tju.edu.cn/info/1005/60240.htm', 0.10718),
#  ('https://news.tju.edu.cn/info/1005/58569.htm', 0.10718),
#  ('https://news.tju.edu.cn/info/1005/55102.htm', 0.10718),
#  ('https://news.tju.edu.cn/info/1005/51277.htm', 0.10718),
#  ('https://news.tju.edu.cn/info/1005/43300.htm', 0.10718),
#  ('https://news.tju.edu.cn/info/1005/43058.htm', 0.10718),
#  ('http://news.nankai.edu.cn/dcxy/system/2021/05/30/030046365.shtml', 0.10718),
#  ('http://news.nankai.edu.cn/nkdxb/system/2021/07/01/030047132.shtml',
#   0.10718),
#  ('http://news.nankai.edu.cn/mtnk/system/2022/11/04/030053449.shtml', 0.10718),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/05/06/030033299.shtml', 0.10718),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/05/06/030033302.shtml', 0.10718),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/05/06/030033298.shtml', 0.10718),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/04/10/000117214.shtml', 0.107),
#  ('http://news.nankai.edu.cn/ywsd/system/2018/07/20/000400954.shtml', 0.107),
#  ('https://news.tju.edu.cn/info/1005/53033.htm', 0.1068),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/04/02/000227537.shtml', 0.1067),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/11/12/000255303.shtml', 0.1067),
#  ('https://news.tju.edu.cn/info/1005/46859.htm', 0.1066),
#  ('http://news.nankai.edu.cn/zhxw/system/2009/05/05/000023485.shtml', 0.1064),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/03/19/000114476.shtml', 0.1063),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/12/03/000211675.shtml', 0.1062),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/09/26/000347478.shtml', 0.1061),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/04/30/000230415.shtml', 0.106),
#  ('http://news.nankai.edu.cn/zhxw/system/2017/03/10/000321774.shtml', 0.106),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/04/24/000446834.shtml', 0.106),
#  ('http://news.nankai.edu.cn/ywsd/system/2016/07/25/000290754.shtml', 0.106),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/08/07/030034774.shtml', 0.1057),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/11/05/000254274.shtml', 0.1056),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/03/10/000436655.shtml', 0.1056),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/04/28/000015655.shtml', 0.1056),
#  ('http://news.nankai.edu.cn/ywsd/system/2016/09/30/000297894.shtml', 0.1056),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/08/02/000040623.shtml', 0.1055),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/04/30/000121945.shtml', 0.1053),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/09/26/000347455.shtml', 0.1053),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/07/05/000032398.shtml', 0.1053),
#  ('http://news.nankai.edu.cn/dcxy/system/2012/06/14/000073255.shtml', 0.1051),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/11/03/000303034.shtml', 0.1049),
#  ('http://news.nankai.edu.cn/nkdxb/system/2012/10/17/000093611.shtml', 0.1049),
#  ('http://news.nankai.edu.cn/zhxw/system/2023/05/27/030056453.shtml', 0.1049),
#  ('http://news.nankai.edu.cn/nkdxb/system/2012/05/18/000068830.shtml', 0.1048),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/07/26/000401674.shtml', 0.1047),
#  ('https://news.tju.edu.cn/info/1003/22470.htm', 0.1046),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/04/13/000228579.shtml', 0.1046),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/07/28/030034655.shtml', 0.1046),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/03/17/000273418.shtml', 0.1045),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/12/10/000259955.shtml', 0.1045),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/07/20/000400915.shtml', 0.1045),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/12/11/000036215.shtml', 0.1044),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/02/27/000056075.shtml', 0.1044),
#  ('http://news.nankai.edu.cn/mtnk/system/2011/11/15/000044855.shtml', 0.1044),
#  ('https://news.tju.edu.cn/info/1017/34839.htm', 0.1043),
#  ('http://news.nankai.edu.cn/dcxy/system/2011/10/17/000041911.shtml', 0.1043),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/12/24/000051163.shtml', 0.1043),
#  ('http://news.nankai.edu.cn/mtnk/system/2012/09/15/000087094.shtml', 0.1043),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/07/24/000401356.shtml', 0.1043),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/11/20/000209684.shtml', 0.1042),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/05/14/000068220.shtml', 0.1042),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/04/15/000118160.shtml', 0.1041),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/01/10/000013303.shtml', 0.1041),
#  ('http://news.nankai.edu.cn/mtnk/system/2014/06/25/000189755.shtml', 0.1041),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/11/26/000257741.shtml', 0.104),
#  ('http://news.nankai.edu.cn/zhxw/system/2016/04/28/000279179.shtml', 0.104),
#  ('http://news.nankai.edu.cn/ywsd/system/2013/09/06/000139194.shtml', 0.104),
#  ('https://news.tju.edu.cn/info/1005/39448.htm', 0.1039),
#  ('https://news.tju.edu.cn/info/1003/39453.htm', 0.1039),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/12/10/000260067.shtml', 0.1039),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/03/23/000274455.shtml', 0.1039),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/05/15/000331646.shtml', 0.1039),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/05/21/000126495.shtml', 0.1039),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/04/29/000179078.shtml', 0.1038),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/03/23/000274643.shtml', 0.1038),
#  ('http://news.nankai.edu.cn/mtnk/system/2014/06/24/000189194.shtml', 0.1038),
#  ('http://news.nankai.edu.cn/mtnk/system/2024/09/18/030063440.shtml', 0.1037),
#  ('http://news.nankai.edu.cn/mtnk/system/2014/06/24/000189174.shtml', 0.1037),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/03/13/000113620.shtml', 0.1036),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/04/14/000175636.shtml', 0.1036),
#  ('http://news.nankai.edu.cn/nkdxb/system/2014/01/07/000162457.shtml', 0.1036),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/05/10/000015782.shtml', 0.1036),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/04/10/000117178.shtml', 0.1036),
#  ('http://news.nankai.edu.cn/ywsd/system/2015/06/06/000237014.shtml', 0.1036),
#  ('http://news.nankai.edu.cn/ywsd/system/2016/12/10/000310234.shtml', 0.1036),
#  ('http://news.nankai.edu.cn/zhxw/system/2009/12/09/000027505.shtml', 0.1035),
#  ('http://news.nankai.edu.cn/mtnk/system/2024/03/20/030060527.shtml', 0.1035),
#  ('http://news.nankai.edu.cn/ywsd/system/2013/08/27/000138196.shtml', 0.1035),
#  ('http://news.nankai.edu.cn/ywsd/system/2013/10/07/000144054.shtml', 0.1035),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/09/14/000345340.shtml', 0.1034),
#  ('http://news.nankai.edu.cn/mtnk/system/2023/03/09/030054734.shtml', 0.1034),
#  ('http://news.nankai.edu.cn/mtnk/system/2014/08/02/000196258.shtml', 0.1034),
#  ('http://news.nankai.edu.cn/ywsd/system/2016/03/28/000275776.shtml', 0.1034),
#  ('http://news.nankai.edu.cn/ywsd/system/2016/04/10/000277135.shtml', 0.1034),
#  ('https://news.tju.edu.cn/info/1005/53456.htm', 0.1033),
#  ('https://news.tju.edu.cn/info/1003/62650.htm', 0.1033),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/05/15/000181406.shtml', 0.1033),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/05/28/000016145.shtml', 0.1033),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/06/07/000072114.shtml', 0.1033),
#  ('http://news.nankai.edu.cn/mtnk/system/2014/05/23/000183475.shtml', 0.1033),
#  ('http://news.nankai.edu.cn/mtnk/system/2017/04/05/000326236.shtml', 0.1033),
#  ('http://news.nankai.edu.cn/ywsd/system/2013/06/21/000131594.shtml', 0.1033),
#  ('http://news.nankai.edu.cn/ywsd/system/2015/12/09/000259755.shtml', 0.1033),
#  ('https://news.tju.edu.cn/info/1017/58837.htm', 0.1032),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/04/25/000178518.shtml', 0.1032),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/11/24/000357554.shtml', 0.1032),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/03/25/000439697.shtml', 0.1032),
#  ('http://news.nankai.edu.cn/nkdxb/system/2013/03/01/000112159.shtml', 0.1032),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/09/24/000018783.shtml', 0.1032),
#  ('http://news.nankai.edu.cn/zhxw/system/2015/10/22/000252354.shtml', 0.1032),
#  ('http://news.nankai.edu.cn/mtnk/system/2012/09/15/000087096.shtml', 0.1032),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/01/21/000218901.shtml', 0.1032),
#  ('http://news.nankai.edu.cn/mtnk/system/2017/08/27/000342578.shtml', 0.1032),
#  ('http://news.nankai.edu.cn/ywsd/system/2015/10/29/000253236.shtml', 0.1032),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/12/27/000312719.shtml', 0.1031),
#  ('http://news.nankai.edu.cn/zhxw/system/2009/05/13/000023683.shtml', 0.1031),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/05/08/000123414.shtml', 0.1031),
#  ('http://news.nankai.edu.cn/ywsd/system/2021/10/21/030048436.shtml', 0.1031),
#  ('https://news.tju.edu.cn/info/1017/44985.htm', 0.103),
#  ('http://news.nankai.edu.cn/dcxy/system/2012/10/21/000094535.shtml', 0.103),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/05/22/000183316.shtml', 0.103),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/10/31/000353107.shtml', 0.103),
#  ('http://news.nankai.edu.cn/nkdxb/system/2013/07/16/000134798.shtml', 0.103),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/12/01/000035922.shtml', 0.103),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/12/10/000158815.shtml', 0.103),
#  ('http://news.nankai.edu.cn/mtnk/system/2021/04/16/030045484.shtml', 0.103),
#  ('https://news.tju.edu.cn/info/1005/69778.htm', 0.1029),
#  ('https://news.tju.edu.cn/info/1005/46479.htm', 0.1029),
#  ('http://news.nankai.edu.cn/zhxw/system/2014/09/22/000202235.shtml', 0.1029),
#  ('http://news.nankai.edu.cn/mtnk/system/2009/07/24/000024805.shtml', 0.1029),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/02/08/000221074.shtml', 0.1029),
#  ('http://news.nankai.edu.cn/mtnk/system/2016/08/02/000291356.shtml', 0.1029),
#  ('http://news.nankai.edu.cn/ywsd/system/2013/07/26/000135754.shtml', 0.1029),
#  ('https://news.tju.edu.cn/info/1017/39606.htm', 0.1028),
#  ('http://news.nankai.edu.cn/dcxy/system/2018/04/23/000378356.shtml', 0.1028),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/10/13/000019168.shtml', 0.1028),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/12/30/000161715.shtml', 0.1028),
#  ('http://news.nankai.edu.cn/ywsd/system/2017/01/09/000314599.shtml', 0.1028),
#  ('https://news.tju.edu.cn/info/1005/57048.htm', 0.1027),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/04/10/000326998.shtml', 0.1027),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/05/15/000331578.shtml', 0.1027),
#  ('http://news.nankai.edu.cn/mtnk/system/2008/01/01/000013155.shtml', 0.1027),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/10/02/000041695.shtml', 0.1027),
#  ('https://news.tju.edu.cn/info/1017/37379.htm', 0.1026),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/10/29/000149534.shtml', 0.1026),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/12/14/000159675.shtml', 0.1026),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/05/19/000281958.shtml', 0.1026),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/03/29/000325178.shtml', 0.1026),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/12/06/000359860.shtml', 0.1026),
#  ('http://news.nankai.edu.cn/dcxy/system/2018/11/05/000416754.shtml', 0.1026),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/11/17/000020187.shtml', 0.1026),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/11/09/000043674.shtml', 0.1026),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/06/30/000076434.shtml', 0.1026),
#  ('http://news.nankai.edu.cn/zhxw/system/2019/04/21/000446280.shtml', 0.1026),
#  ('http://news.nankai.edu.cn/mtnk/system/2016/06/10/000284458.shtml', 0.1026),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/05/26/000184280.shtml', 0.1025),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/05/18/000030735.shtml', 0.1025),
#  ('http://news.nankai.edu.cn/mtnk/system/2010/11/22/000035518.shtml', 0.1025),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/04/20/000118881.shtml', 0.1024),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/09/28/000347762.shtml', 0.1024),
#  ('http://news.nankai.edu.cn/dcxy/system/2020/10/29/030041463.shtml', 0.1024),
#  ('http://news.nankai.edu.cn/dcxy/system/2021/04/20/030045562.shtml', 0.1024),
#  ('http://news.nankai.edu.cn/dcxy/system/2022/03/05/030050496.shtml', 0.1024),
#  ('http://news.nankai.edu.cn/zhxw/system/2023/09/07/030057748.shtml', 0.1024),
#  ('http://news.nankai.edu.cn/ywsd/system/2021/03/22/030045018.shtml', 0.1024),
#  ('https://news.tju.edu.cn/info/1003/70049.htm', 0.1023),
#  ('http://news.nankai.edu.cn/dcxy/system/2011/05/25/000039306.shtml', 0.1023),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/11/06/000151357.shtml', 0.1023),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/11/03/000207316.shtml', 0.1023),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/04/06/000276728.shtml', 0.1023),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/08/01/000017652.shtml', 0.1023),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/11/07/000019921.shtml', 0.1023),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/05/29/000070554.shtml', 0.1023),
#  ('http://news.nankai.edu.cn/mtnk/system/2009/08/20/000025097.shtml', 0.1023),
#  ('http://news.nankai.edu.cn/mtnk/system/2016/06/11/000284536.shtml', 0.1023),
#  ('http://news.nankai.edu.cn/mtnk/system/2017/06/20/000335314.shtml', 0.1023),
#  ('https://news.tju.edu.cn/info/1017/43891.htm', 0.1022),
#  ('http://news.nankai.edu.cn/dcxy/system/2011/05/26/000039327.shtml', 0.1022),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/03/16/000169638.shtml', 0.1022),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/04/22/000177894.shtml', 0.1022),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/11/02/000353557.shtml', 0.1022),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/04/25/000015626.shtml', 0.1022),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/10/26/000034490.shtml', 0.1022),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/04/19/000038427.shtml', 0.1022),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/04/29/000121754.shtml', 0.1022),
#  ('http://news.nankai.edu.cn/zhxw/system/2015/12/15/000260739.shtml', 0.1022),
#  ('http://news.nankai.edu.cn/mtnk/system/2022/01/22/030050091.shtml', 0.1022),
#  ('http://news.nankai.edu.cn/mtnk/system/2022/07/04/030051960.shtml', 0.1022),
#  ('http://news.nankai.edu.cn/mtnk/system/2012/08/15/000081274.shtml', 0.1022),
#  ('http://news.nankai.edu.cn/mtnk/system/2012/09/09/000085336.shtml', 0.1022),
#  ('http://news.nankai.edu.cn/ywsd/system/2012/12/26/000107397.shtml', 0.1022),
#  ('http://news.nankai.edu.cn/ywsd/system/2015/12/03/000258806.shtml', 0.1022),
#  ('http://news.nankai.edu.cn/ywsd/system/2016/11/25/000307959.shtml', 0.1022),
#  ('http://news.nankai.edu.cn/ywsd/system/2017/12/08/000360174.shtml', 0.1022),
#  ('https://news.tju.edu.cn/info/1017/37287.htm', 0.1021),
#  ('http://news.nankai.edu.cn/dcxy/system/2012/06/04/000071535.shtml', 0.1021),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/05/05/000179815.shtml', 0.1021),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/03/24/000274935.shtml', 0.1021),
#  ('http://news.nankai.edu.cn/dcxy/system/2021/01/21/030044427.shtml', 0.1021),
#  ('http://news.nankai.edu.cn/dcxy/system/2021/06/23/030046915.shtml', 0.1021),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/04/08/000116934.shtml', 0.1021),
#  ('http://news.nankai.edu.cn/zhxw/system/2014/11/19/000209557.shtml', 0.1021),
#  ('http://news.nankai.edu.cn/zhxw/system/2019/05/21/030033567.shtml', 0.1021),
#  ('http://news.nankai.edu.cn/mtnk/system/2022/01/22/030050092.shtml', 0.1021),
#  ('http://news.nankai.edu.cn/mtnk/system/2014/04/14/000175614.shtml', 0.1021),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/06/23/000239194.shtml', 0.1021),
#  ('http://news.nankai.edu.cn/ywsd/system/2015/04/30/000230365.shtml', 0.1021),
#  ('https://news.tju.edu.cn/info/1005/46853.htm', 0.102),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/03/22/000114837.shtml', 0.102),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/05/20/000182474.shtml', 0.102),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/05/09/000180459.shtml', 0.102),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/04/14/000277623.shtml', 0.102),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/04/08/000442535.shtml', 0.102),
#  ('http://news.nankai.edu.cn/dcxy/system/2020/05/23/030039305.shtml', 0.102),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/10/17/000034186.shtml', 0.102),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/06/05/000039570.shtml', 0.102),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/07/15/000134636.shtml', 0.102),
#  ('http://news.nankai.edu.cn/mtnk/system/2010/08/07/000032826.shtml', 0.102),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/12/29/030037106.shtml', 0.102),
#  ('http://news.nankai.edu.cn/ywsd/system/2013/04/25/000120454.shtml', 0.102),
#  ('http://news.nankai.edu.cn/ywsd/system/2013/09/18/000140821.shtml', 0.102),
#  ('http://news.nankai.edu.cn/ywsd/system/2015/06/24/000239279.shtml', 0.102),
#  ('https://news.tju.edu.cn/info/1005/58508.htm', 0.1019),
#  ('https://news.tju.edu.cn/info/1005/57773.htm', 0.1019),
#  ('https://news.tju.edu.cn/info/1005/44537.htm', 0.1019),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/04/10/000174515.shtml', 0.1019),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/06/02/000283504.shtml', 0.1019),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/10/24/000300957.shtml', 0.1019),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/04/13/000444397.shtml', 0.1019),
#  ('http://news.nankai.edu.cn/dcxy/system/2023/03/10/030054753.shtml', 0.1019),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/07/20/000017475.shtml', 0.1019),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/06/25/000032135.shtml', 0.1019),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/11/23/000035584.shtml', 0.1019),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/03/14/000113894.shtml', 0.1019),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/04/17/000118499.shtml', 0.1019),
#  ('http://news.nankai.edu.cn/zhxw/system/2014/05/20/000182375.shtml', 0.1019),
#  ('http://news.nankai.edu.cn/zhxw/system/2023/08/16/030057472.shtml', 0.1019),
#  ('http://news.nankai.edu.cn/ywsd/system/2018/05/15/000382337.shtml', 0.1019),
#  ('https://news.tju.edu.cn/info/1003/70050.htm', 0.1018),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/04/26/000120694.shtml', 0.1018),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/12/05/000211996.shtml', 0.1018),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/05/19/000281944.shtml', 0.1018),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/11/23/030036479.shtml', 0.1018),
#  ('http://news.nankai.edu.cn/dcxy/system/2020/05/23/030039303.shtml', 0.1018),
#  ('http://news.nankai.edu.cn/dcxy/system/2023/12/10/030059313.shtml', 0.1018),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/05/18/000030737.shtml', 0.1018),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/10/16/000034174.shtml', 0.1018),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/05/15/000068396.shtml', 0.1018),
#  ('http://news.nankai.edu.cn/zhxw/system/2015/04/12/000228459.shtml', 0.1018),
#  ('http://news.nankai.edu.cn/zhxw/system/2015/12/09/000259796.shtml', 0.1018),
#  ('http://news.nankai.edu.cn/zhxw/system/2016/01/07/000264154.shtml', 0.1018),
#  ('http://news.nankai.edu.cn/zhxw/system/2017/11/29/000358237.shtml', 0.1018),
#  ('http://news.nankai.edu.cn/mtnk/system/2009/05/26/000023956.shtml', 0.1018),
#  ('http://news.nankai.edu.cn/mtnk/system/2012/08/04/000080459.shtml', 0.1018),
#  ('http://news.nankai.edu.cn/mtnk/system/2017/08/27/000342576.shtml', 0.1018),
#  ('http://news.nankai.edu.cn/ywsd/system/2015/12/16/000260837.shtml', 0.1018),
#  ('https://news.tju.edu.cn/info/1005/71093.htm', 0.1017),
#  ('https://news.tju.edu.cn/info/1017/40147.htm', 0.1017),
#  ('http://news.nankai.edu.cn/dcxy/system/2011/10/18/000042003.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/dcxy/system/2012/12/06/000104608.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/12/03/000157835.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/04/21/000177695.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/04/23/000178154.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/05/01/000179474.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/11/02/030036193.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/dcxy/system/2020/11/01/030041521.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/dcxy/system/2021/04/20/030045571.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/dcxy/system/2022/05/31/030051554.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/dcxy/system/2023/04/17/030055467.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/nkdxb/system/2012/12/29/000107809.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/nkdxb/system/2013/05/17/000125456.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/10/08/000019053.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/10/21/000034335.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/04/26/000064815.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/zhxw/system/2015/12/13/000260417.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/zhxw/system/2017/03/29/000325277.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/mtnk/system/2021/12/18/030049600.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/mtnk/system/2024/04/07/030060806.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/04/03/000116341.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/mtnk/system/2014/11/09/000208136.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/08/08/000404314.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/08/07/030034773.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/ywsd/system/2019/03/09/000436474.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/ywsd/system/2019/12/06/030036728.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/ywsd/system/2022/02/05/030050226.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/ywsd/system/2013/03/11/000113214.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/ywsd/system/2013/10/01/000143514.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/ywsd/system/2015/09/25/000249614.shtml', 0.1017),
#  ('http://news.nankai.edu.cn/ywsd/system/2017/11/14/000355775.shtml', 0.1017),
#  ('https://news.tju.edu.cn/info/1005/21424.htm', 0.1016),
#  ('https://news.tju.edu.cn/info/1003/45266.htm', 0.1016),
#  ('https://news.tju.edu.cn/info/1017/38392.htm', 0.1016),
#  ('http://news.nankai.edu.cn/dcxy/system/2011/10/17/000041914.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/09/27/000142494.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/04/11/000175274.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/dcxy/system/2021/04/25/030045661.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/dcxy/system/2021/05/08/030045909.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/dcxy/system/2022/01/28/030050195.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/dcxy/system/2023/04/26/030055755.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/nkdxb/system/2012/10/12/000092794.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/nkdxb/system/2013/10/25/000148479.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/09/16/000018562.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/03/30/000061156.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/03/19/000114318.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/zhxw/system/2017/03/04/000320614.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/zhxw/system/2017/03/29/000325181.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/zhxw/system/2021/06/01/030046388.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/mtnk/system/2024/05/07/030061416.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/09/17/000140734.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/mtnk/system/2016/11/03/000303036.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/07/15/000400259.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/05/06/030033301.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/mtnk/system/2020/06/17/030039676.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/ywsd/system/2019/03/08/000436354.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/ywsd/system/2013/10/03/000143734.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/ywsd/system/2016/12/09/000309936.shtml', 0.1016),
#  ('http://news.nankai.edu.cn/ywsd/system/2017/06/15/000334875.shtml', 0.1016),
#  ('https://news.tju.edu.cn/info/1005/66006.htm', 0.1015),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/05/13/000124998.shtml', 0.1015),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/03/20/000170295.shtml', 0.1015),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/06/11/000237434.shtml', 0.1015),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/12/03/000258875.shtml', 0.1015),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/12/03/000258856.shtml', 0.1015),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/11/03/000302958.shtml', 0.1015),
#  ('http://news.nankai.edu.cn/dcxy/system/2022/04/18/030050963.shtml', 0.1015),
#  ('http://news.nankai.edu.cn/dcxy/system/2024/03/10/030060336.shtml', 0.1015),
#  ('http://news.nankai.edu.cn/nkdxb/system/2013/04/01/000116105.shtml', 0.1015),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/11/08/000043574.shtml', 0.1015),
#  ('http://news.nankai.edu.cn/zhxw/system/2019/06/17/030034080.shtml', 0.1015),
#  ('http://news.nankai.edu.cn/mtnk/system/2012/09/08/000085176.shtml', 0.1015),
#  ('http://news.nankai.edu.cn/mtnk/system/2016/06/10/000284474.shtml', 0.1015),
#  ('http://news.nankai.edu.cn/ywsd/system/2023/05/23/030056361.shtml', 0.1015),
#  ('http://news.nankai.edu.cn/ywsd/system/2024/10/30/030064147.shtml', 0.1015),
#  ('http://news.nankai.edu.cn/ywsd/system/2016/03/11/000272175.shtml', 0.1015),
#  ('http://news.nankai.edu.cn/ywsd/system/2017/12/14/000360974.shtml', 0.1015),
#  ('https://news.tju.edu.cn/info/1005/56194.htm', 0.1014),
#  ('https://news.tju.edu.cn/info/1003/70048.htm', 0.1014),
#  ('https://news.tju.edu.cn/info/1003/23138.htm', 0.1014),
#  ('https://news.tju.edu.cn/info/1013/59565.htm', 0.1014),
#  ('http://news.nankai.edu.cn/dcxy/system/2011/10/19/000042016.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/dcxy/system/2012/10/21/000094614.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/06/04/000236751.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/09/14/000247974.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/03/24/000274995.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/05/30/000283215.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/dcxy/system/2023/04/14/030055425.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/dcxy/system/2023/12/06/030059208.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/01/10/000013302.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/11/19/000020233.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/10/17/000034185.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/01/20/000036966.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/05/16/000068455.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/11/06/000098674.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/04/04/000116497.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/zhxw/system/2017/10/31/000353254.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/zhxw/system/2021/06/16/030046670.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/mtnk/system/2021/12/16/030049565.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/mtnk/system/2023/12/11/030059323.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/mtnk/system/2010/11/24/000035621.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/mtnk/system/2012/09/17/000087462.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/mtnk/system/2016/04/06/000276794.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/ywsd/system/2019/03/12/000436974.shtml', 0.1014),
#  ('http://news.nankai.edu.cn/dcxy/system/2011/10/18/000041948.shtml', 0.1013),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/10/28/000149295.shtml', 0.1013),
# ...
#  ('http://news.nankai.edu.cn/zhxw/system/2013/11/17/000154074.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/zhxw/system/2014/11/26/000210660.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/zhxw/system/2016/03/29/000276036.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/zhxw/system/2017/11/29/000358236.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/zhxw/system/2021/12/24/030049696.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/mtnk/system/2023/04/11/030055371.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/mtnk/system/2010/11/30/000035883.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/mtnk/system/2011/09/08/000041046.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/mtnk/system/2011/11/15/000044786.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/mtnk/system/2017/03/27/000324602.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/12/17/000423917.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/05/09/030033362.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/10/23/030035986.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/ywsd/system/2024/11/07/030064289.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/ywsd/system/2012/12/13/000105654.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/ywsd/system/2014/08/11/000196816.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/ywsd/system/2015/05/12/000232314.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/ywsd/system/2015/09/21/000249054.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/ywsd/system/2016/07/30/000291254.shtml', 0.1008),
#  ('http://news.nankai.edu.cn/ywsd/system/2016/11/04/000303134.shtml', 0.1008),
#  ('https://news.tju.edu.cn/info/1003/22945.htm', 0.1007),
#  ('http://news.nankai.edu.cn/dcxy/system/2011/05/25/000039309.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/03/15/000114014.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/09/28/000142876.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/09/28/000142874.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/09/27/000142496.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/09/25/000202561.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/04/29/000230258.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/05/11/000280697.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/09/23/000297055.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/10/20/000300275.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/12/22/000312176.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/dcxy/system/2018/10/15/000413260.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/03/22/000439194.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/05/15/030033458.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/05/20/030033547.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/dcxy/system/2021/12/31/030049806.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/nkdxb/system/2013/07/19/000135299.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/06/11/000016555.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/10/20/000019360.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/10/16/000019241.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/11/08/000019948.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/05/17/000030674.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/zhxw/system/2011/10/10/000041778.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/05/11/000067857.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/09/30/000143454.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/zhxw/system/2016/12/29/000313196.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/zhxw/system/2018/02/02/000367434.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/zhxw/system/2019/03/26/000439799.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/zhxw/system/2019/07/03/030034197.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/zhxw/system/2019/11/01/030036177.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/mtnk/system/2021/06/03/030046478.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/mtnk/system/2022/06/24/030051834.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/mtnk/system/2023/05/31/030056535.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/mtnk/system/2012/09/09/000085339.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/09/30/000143478.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/mtnk/system/2014/04/21/000177603.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/mtnk/system/2014/08/02/000196256.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/11/03/000253835.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/06/09/000389354.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/07/10/000399735.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/mtnk/system/2020/04/16/030038776.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/ywsd/system/2019/05/04/030033203.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/ywsd/system/2020/11/07/030041638.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/ywsd/system/2020/12/10/030043151.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/ywsd/system/2021/12/30/030049775.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/ywsd/system/2022/06/18/030051742.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/ywsd/system/2014/10/07/000203834.shtml', 0.1007),
#  ('http://news.nankai.edu.cn/ywsd/system/2017/06/19/000335234.shtml', 0.1007),
#  ('https://news.tju.edu.cn/info/1005/48443.htm', 0.1006),
#  ('https://news.tju.edu.cn/info/1003/69775.htm', 0.1006),
#  ('https://news.tju.edu.cn/info/1003/56291.htm', 0.1006),
#  ('http://news.nankai.edu.cn/dcxy/system/2011/04/28/000038757.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/dcxy/system/2011/05/11/000039010.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/04/30/000230361.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/dcxy/system/2018/06/12/000389974.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/dcxy/system/2020/11/18/030041805.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/dcxy/system/2022/01/19/030050030.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/09/06/000018342.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/zhxw/system/2009/04/22/000023167.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/zhxw/system/2009/10/24/000026405.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/01/03/000028027.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/05/02/000065938.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/zhxw/system/2014/05/21/000182895.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/zhxw/system/2019/04/03/000441515.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/mtnk/system/2021/06/01/030046414.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/01/12/000217368.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/mtnk/system/2016/07/18/000289614.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/mtnk/system/2019/10/11/030035673.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/ywsd/system/2019/05/15/030033493.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/ywsd/system/2024/01/19/030059896.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/ywsd/system/2014/01/25/000164215.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/ywsd/system/2014/04/28/000178935.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/ywsd/system/2015/12/06/000259356.shtml', 0.1006),
#  ('http://news.nankai.edu.cn/ywsd/system/2016/12/19/000311619.shtml', 0.1006),
#  ('https://news.tju.edu.cn/info/1005/71785.htm', 0.1005),
#  ('https://news.tju.edu.cn/info/1005/69881.htm', 0.1005),
#  ('https://news.tju.edu.cn/info/1003/23378.htm', 0.1005),
#  ('https://news.tju.edu.cn/info/1016/44804.htm', 0.1005),
#  ('https://news.tju.edu.cn/info/1016/40032.htm', 0.1005),
#  ('http://news.nankai.edu.cn/dcxy/system/2011/11/01/000042382.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/03/18/000114155.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/03/31/000172177.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/05/28/000127814.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/11/06/000151397.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/10/29/000149496.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/04/28/000179037.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/11/11/000255240.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/12/10/000259996.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/dcxy/system/2018/10/28/000414757.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/05/14/030033404.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/04/13/000444396.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/05/13/030033394.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/05/05/030033294.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/dcxy/system/2020/01/04/030037211.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/dcxy/system/2020/12/11/030043190.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/nkdxb/system/2013/04/08/000116963.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/nkdxb/system/2013/09/23/000141419.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/zhxw/system/2007/12/11/000012850.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/03/06/000014433.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/07/04/000017080.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/zhxw/system/2009/12/26/000027871.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/03/22/000060039.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/05/03/000066135.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/zhxw/system/2013/04/30/000121857.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/zhxw/system/2016/12/06/000309376.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/zhxw/system/2017/11/15/000356056.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/zhxw/system/2018/05/25/000385375.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/zhxw/system/2020/11/25/030042410.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/zhxw/system/2021/10/09/030048246.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/zhxw/system/2021/11/26/030049134.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/mtnk/system/2021/04/18/030045506.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/mtnk/system/2024/09/02/030063151.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/mtnk/system/2012/08/17/000081534.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/mtnk/system/2012/09/15/000087095.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/09/30/000143476.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/mtnk/system/2016/11/02/000302617.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/mtnk/system/2018/06/25/000394275.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/ywsd/system/2019/07/26/030034630.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/ywsd/system/2023/10/24/030058468.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/ywsd/system/2013/09/17/000140754.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/ywsd/system/2017/04/18/000328417.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/ywsd/system/2017/05/29/000333174.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/ywsd/system/2018/02/12/000368114.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/ywsd/system/2018/05/05/000380214.shtml', 0.1005),
#  ('http://news.nankai.edu.cn/ywsd/system/2018/07/28/000402074.shtml', 0.1005),
#  ('https://news.tju.edu.cn/info/1005/72923.htm', 0.1004),
#  ('https://news.tju.edu.cn/info/1005/69782.htm', 0.1004),
#  ('https://news.tju.edu.cn/info/1005/68069.htm', 0.1004),
#  ('https://news.tju.edu.cn/info/1003/56836.htm', 0.1004),
#  ('https://news.tju.edu.cn/info/1003/51372.htm', 0.1004),
#  ('https://news.tju.edu.cn/info/1003/23200.htm', 0.1004),
#  ('http://news.nankai.edu.cn/dcxy/system/2011/03/29/000037925.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/dcxy/system/2012/10/20/000094494.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/dcxy/system/2012/11/27/000103134.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/dcxy/system/2013/09/28/000142834.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/07/29/000244414.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/dcxy/system/2015/12/13/000260434.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/dcxy/system/2016/05/10/000280557.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/dcxy/system/2017/04/01/000325916.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/03/24/000439555.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/11/29/030036635.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/12/25/030037044.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/dcxy/system/2021/05/30/030046368.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/dcxy/system/2023/04/18/030055515.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/dcxy/system/2023/04/25/030055715.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/dcxy/system/2023/05/15/030056134.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/dcxy/system/2024/04/30/030061356.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/nkdxb/system/2013/06/21/000131636.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/11/03/000019785.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/11/24/000020341.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/06/24/000032081.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/06/24/000032062.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/zhxw/system/2010/09/30/000033820.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/05/25/000070114.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/zhxw/system/2014/03/24/000170958.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/zhxw/system/2016/04/05/000276616.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/zhxw/system/2018/11/24/000420037.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/zhxw/system/2019/12/24/030037021.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/zhxw/system/2021/10/26/030048520.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/zhxw/system/2023/10/13/030058249.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/mtnk/system/2021/04/09/030045377.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/10/07/000143995.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/12/08/000158619.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/ywsd/system/2023/03/07/030054693.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/ywsd/system/2013/10/05/000143874.shtml', 0.1004),
#  ('http://news.nankai.edu.cn/ywsd/system/2013/07/27/000135794.shtml', 0.1004),
#  ('https://news.tju.edu.cn/info/1005/48453.htm', 0.1003),
#  ('https://news.tju.edu.cn/info/1005/46271.htm', 0.1003),
#  ('https://news.tju.edu.cn/info/1003/23207.htm', 0.1003),
#  ('https://news.tju.edu.cn/info/1017/48281.htm', 0.1003),
#  ('https://news.tju.edu.cn/info/1016/35268.htm', 0.1003),
#  ('http://news.nankai.edu.cn/dcxy/system/2011/09/21/000041295.shtml', 0.1003),
#  ('http://news.nankai.edu.cn/dcxy/system/2012/11/23/000102378.shtml', 0.1003),
#  ('http://news.nankai.edu.cn/dcxy/system/2014/04/25/000178499.shtml', 0.1003),
#  ('http://news.nankai.edu.cn/dcxy/system/2019/05/20/030033546.shtml', 0.1003),
#  ('http://news.nankai.edu.cn/dcxy/system/2023/03/30/030055164.shtml', 0.1003),
#  ('http://news.nankai.edu.cn/zhxw/system/2008/08/02/000017676.shtml', 0.1003),
#  ('http://news.nankai.edu.cn/zhxw/system/2009/02/10/000021598.shtml', 0.1003),
#  ('http://news.nankai.edu.cn/zhxw/system/2009/05/04/000023455.shtml', 0.1003),
#  ('http://news.nankai.edu.cn/zhxw/system/2012/02/25/000055955.shtml', 0.1003),
#  ('http://news.nankai.edu.cn/zhxw/system/2016/10/18/000299815.shtml', 0.1003),
#  ('http://news.nankai.edu.cn/zhxw/system/2021/01/21/030044422.shtml', 0.1003),
#  ('http://news.nankai.edu.cn/zhxw/system/2023/05/19/030056220.shtml', 0.1003),
#  ('http://news.nankai.edu.cn/mtnk/system/2010/08/04/000032801.shtml', 0.1003),
#  ('http://news.nankai.edu.cn/mtnk/system/2013/10/09/000144315.shtml', 0.1003),
#  ('http://news.nankai.edu.cn/mtnk/system/2015/06/23/000239095.shtml', 0.1003),
#  ...]

# %%
import re

def search_documents(input_query: str, all_info_dict: dict):
    """
    查询包含附件链接的条目，支持对附件标题、描述、链接的搜索。
    
    :param input_query: 用户输入的查询关键字或正则表达式
    :param all_info_dict: 包含所有网页数据的字典
    :return: 带有附件链接的查询结果列表
    """
    # 转换通配符为正则表达式
    wildcard_to_regex = lambda s: re.sub(r"(\*)", ".*", re.sub(r"(\?)", ".", re.escape(s)))
    regex_query = wildcard_to_regex(input_query)
    
    # 存放匹配结果
    matched_results = []
    
    for key, row in all_info_dict.items():
        doc_link = row.get("doc_link")
        if pd.isna(doc_link):  # 如果 doc_link 为空，则跳过
            continue
        
        # 搜索匹配：标题、描述、附件链接
        title = row.get("title", "")
        description = row.get("description", "")
        if (re.search(regex_query, title) or
            re.search(regex_query, description) or
            re.search(regex_query, doc_link)):
            matched_results.append({
                "title": title,
                "url": row.get("url"),
                "description": description,
                "doc_link": doc_link
            })
    
    return matched_results

# %%
# 查询所有 PDF 附件
results = search_documents("*.pdf", all_info_dict)
results1 = search_documents("onlinelibrary", all_info_dict)#搜索链接名
print(results)
# Out:
# [{'title': '今晚报：简讯-天津大学新闻网', 'url': None, 'description': '今晚报：简讯-天津大学新闻网', 'doc_link': ' http://epaper.jwb.com.cn/jwb/resfile/2018-12-17/02/jwb2018121702.pdf'}, {'title': '天津大学生命科学学院王亚鑫、叶升团队在高致病性病毒纳米抗体研究中取得系列进展-天津大学新闻网', 'url': None, 'description': '天津大学生命科学学院王亚鑫、叶升团队在高致病性病毒纳米抗体研究中取得系列进展-天津大学新闻网', 'doc_link': 'https://www.nature.com/articles/s41467-024-51414-6.pdf'}]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd
def load_file_links_from_csv(file_path):  
    """  
    Load file links from a CSV file and return as a DataFrame.  

    Parameters:  
    file_path (str): The path to the CSV file.  

    Returns:  
    DataFrame: A DataFrame containing file links.  
    """  
    return pd.read_csv(file_path)  

def search_file_link(file_df, query):  
    """  
    Search for a file link based on the query in the DataFrame.  

    Parameters:  
    file_df (DataFrame): The DataFrame containing file links.  
    query (str): The query to search for.  

    Returns:  
    dict: A dictionary with link and description if found, else None.  
    """  
     # 处理缺失值  
    file_df = file_df.dropna(subset=['title'])  
    filtered_files = file_df[file_df['title'].str.contains(query, case=False)]  
    if not filtered_files.empty:  
        return filtered_files.iloc[0].to_dict()  
    return None  

def test_file_link_search(query, file_df):  
    file_link = search_file_link(file_df, query)  
    if file_link:  
        print(f"文件链接: {file_link['url']} - {file_link['title']}")  
    else:  
        print("未找到匹配的文件链接。")

# %%
# Step 1: Load file links from CSV  
output_csv_file = '../spider/file_links.csv'  # CSV 文件的路径  
file_sparse_links = load_file_links_from_csv(output_csv_file)  

# Step 2: Test search function  
test_query = "新冠肺炎防控指南漫画（汉西双语）"  # 示例查询  
test_file_link_search(test_query, file_sparse_links)
# Out:
# 文件链接: http://n1.sinaimg.cn/tj/7d076bde/20200702/xi.pdf - 新冠肺炎防控指南漫画（汉西双语）
